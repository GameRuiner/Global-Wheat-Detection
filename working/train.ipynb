# %%
from ultralytics import YOLO

# %%
model = YOLO("yolov8n.pt")  # load a pretrained model (recommended for training)
model.train(data="dataset.yaml", epochs=3, imgsz=1024, batch=8)
# Out:
# Ultralytics YOLOv8.2.4  Python-3.11.2 torch-2.0.1+cpu CPU (12th Gen Intel Core(TM) i7-12700H)
# ...
